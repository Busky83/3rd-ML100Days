# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    計算MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - name: MSE
    """
    mse = MSE = sum((yp-y)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 239.246
# The Mean absolute error is 11.911

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# Shared Cars Locations
# Ans1:
# 公眾利益
# 隨著時代進步，越來越多共享經濟崛起，藉由共享汽車的概念可以提供人們短暫性使用汽車的需求，此外更可以降低都市停車格供應不足問題。
# 然而共享汽車勢必遇到的問題就是租車地是否符合使用者的需求，如果起初或是使用後車子都停在偏僻地區，勢必造成下一位使用者的不便，因此車子的停放地區非常重要，根據車子停放位置的分析，可以最大化平衡汽車的使用及提供。
# Ans2:
# 網路爬蟲或是格式化表單
# 以色列特拉維夫城市2017年10月發起了一個汽車共享的專案，
#     這些資料是AutoTel website花費數個月每兩分鐘根據這些車子停在哪所收集而來的，
# 使用csv的格式儲存於Google Storage
# Ans3:
# 結構化
# Ans4:
# 這組資料主要的目的是為了解決共享汽車的提供地點是否與使用者需要的地點符合，在沒有人使用
# 的地點停車增加費用，在多人使用的地點停車，降低費用，藉此平衡使用車的停車地點與使用者需要使用車子的地點。因此個人認為採用Regression中的MAE預測不同地點的使用人數，以達到評估作用。
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績即代表員工載客率上升，員工等候乘客的時間下降，因此假設我讓每位員工等候乘客搭乘的時間降至最低，即代表每位員工的載客效率提升最高，業績最好，所以只要能預測哪個時段哪個地點最有可能有客人，藉此達到降低司機等候乘客時間。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 首先影響業績的有兩類資料:
# 1.顧客
# 哪個地方有最多乘客?
# 哪個時端有最多乘客?
# 資料可以從乘客身上回傳，可能是乘客使用APP、電話叫車，或是司機路上看到，紀錄他們的時段以及位置，統計出哪個時端哪個位置乘客較多。
# 2.司機
# 我讓每位加入車隊的司機每天固定回報他們等候的位置，並且回報是否有乘客上車，統計出在哪個地點花費多少時間等候乘客上車，哪個時端工作的效益最大。
# 3. 蒐集而來的資料型態為何
# 結構化的資料
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 使用MAE來越測不同時段、地點的乘客。
